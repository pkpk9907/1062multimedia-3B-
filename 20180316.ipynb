# %%
i = 4 #int

# %%
type(i)
# Out:
# int

# %%
f = 3.14

# %%
type(f)
# Out:
# float

# %%
b = True

# %%
type(b)
# Out:
# bool

# %%
hungry = True

# %%
sleep = False

# %%
not hungry
# Out:
# False

# %%
hungry and sleep
# Out:
# False

# %%
hungry or sleep
# Out:
# True

# %%
ss = "This is a string"

# %%
ss
# Out:
# 'This is a string'

# %%
a = [1,2,3,4,5]

# %%
type(a)
# Out:
# list

# %%
print(a)
# Out:
# [1, 2, 3, 4, 5]

# %%
len(a)
# Out:
# 5

# %%
a[1]
# Out:
# 2

# %%
a[0:2]
# Out:
# [1, 2]

# %%
a[1:]
# Out:
# [2, 3, 4, 5]

# %%
a[-1]
# Out:
# 5

# %%
a[:-2]
# Out:
# [1, 2, 3]

# %%
a[0]=2

# %%
a[0]
# Out:
# 2

# %%
I = (1,2,3)

# %%
type(I)
# Out:
# tuple

# %%
I[0]
# Out:
# 1

# %%
I[0]=2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-07fa892e4781> in <module>()
# ----> 1 I[0]=2
#
# TypeError: 'tuple' object does not support item assignment

# %%
d = {'foo':1,'bar':2.3,'s':'my first dictionary'}

# %%
print(d['s'])
# Out:
# my first dictionary

# %%
n = None

# %%
type(n)
# Out:
# NoneType

# %%
print("Our float value is %s. Our int value is %s." % (f,i))
# Out:
# Our float value is 3.14. Our int value is 4.

# %%
from skimage import io

img1=io.imread('image_01.jpg', as_grey=True)

print(type(img1))
print(img1.shape)

io.imshow(img1)
io.show()
# Out:
# <class 'numpy.ndarray'>
# (288, 512)
